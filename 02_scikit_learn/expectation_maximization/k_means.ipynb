# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# help(pd.read_csv)

# %%
file = pd.read_csv('densityPCA/Archive/densityEstimation/densityEstimationData.txt', header=None)
print(file.head())
data = file.iloc[:,0:2]
labels = file.iloc[:,2]
# Out:
#         0       1  2
# 0 -5.2393  1.2388  2
# 1  4.0437  4.5473  1
# 2  5.9902  7.5401  3
# 3 -1.3144  2.8117  2
# 4  4.8442  4.9534  3

# %%
file[2].drop_duplicates()
# Out:
# 0    2
# 1    1
# 2    3
# Name: 2, dtype: int64

# %%
plt.scatter(data[0], data[1])

# %%
from sklearn.cluster import KMeans

# %%
#number of clusters
kmeans = KMeans(n_clusters=3)

# Fitting the input data
kmeans = kmeans.fit(data)

# Getting the cluster labels
labels = kmeans.predict(data)

# Centroid values
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[ 5.84778889,  7.76286222],
#        [-3.12382854,  1.93590058],
#        [ 4.292234  ,  2.13507528]])

# %%
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', s=200, alpha=0.5);
